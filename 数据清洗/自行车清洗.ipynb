# %%
# %matplotlib widget
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#import pygwalker as pyg
#import mitosheet

# 加载数据
df1=pd.read_excel("uncleaned bike sales data.xlsx")
#mitosheet.sheet()
#show(df1)
# 启动PyGWalker界面
#walker = pyg.walk(df1)

# %%
df1=pd.read_excel("uncleaned bike sales data.xlsx")

# %%
df1.head()
# Out:
#    Sales_Order #       Date  Day     Month  Year  Customer_Age  \
# 0         261695 2021-12-01  1.0  December  2021            39
# 1         261695 2021-12-01  1.0  December  2021            44
# 2         261697 2021-12-02  2.0  December  2021            37
# 3         261698 2021-12-02  2.0  December  2021            31
# 4         261699 2021-12-03  3.0  December  2021            37
#
#               Age_Group Customer_Gender         Country            State  \
# 0        Adults (35-64)               F   United States       California
# 1        Adults (35-64)               M  United Kingdom          England
# 2        Adults (35-64)               M   United States       California
# 3  Young Adults (25-34)               F       Australia  New South Wales
# 4        Adults (35-64)               F  United  States       California
#
#   Product_Category    Sub_Category        Product_Description  Order_Quantity  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sales_Order #        89 non-null     int64
#  1   Date                 89 non-null     datetime64[ns]
#  2   Day                  88 non-null     float64
#  3   Month                89 non-null     object
#  4   Year                 89 non-null     int64
#  5   Customer_Age         89 non-null     int64
#  6   Age_Group            88 non-null     object
#  7   Customer_Gender      89 non-null     object
#  8   Country              89 non-null     object
#  9   State                89 non-null     object
#  10  Product_Category     89 non-null     object
#  11  Sub_Category         89 non-null     object
#  12  Product_Description  88 non-null     object
#  13  Order_Quantity       88 non-null     float64
#  14   Unit_Cost           89 non-null     int64
# ...

# %%
df1.columns = df1.columns.str.strip()  # 清理首尾空格

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sales_Order #        89 non-null     int64
#  1   Date                 89 non-null     datetime64[ns]
#  2   Day                  88 non-null     float64
#  3   Month                89 non-null     object
#  4   Year                 89 non-null     int64
#  5   Customer_Age         89 non-null     int64
#  6   Age_Group            88 non-null     object
#  7   Customer_Gender      89 non-null     object
#  8   Country              89 non-null     object
#  9   State                89 non-null     object
#  10  Product_Category     89 non-null     object
#  11  Sub_Category         89 non-null     object
#  12  Product_Description  88 non-null     object
#  13  Order_Quantity       88 non-null     float64
#  14  Unit_Cost            89 non-null     int64
# ...

# %%
df1["Order_Quantity"]=df1["Order_Quantity"].astype("Int64")
df1["Sales_Order #"]=df1["Sales_Order #"].astype("str")

# %%
df1=df1.drop(['Day','Month','Year'],axis=1)

# %%
df1.describe()
# Out:
#                                 Date  Customer_Age  Order_Quantity  \
# count                             89     89.000000            88.0
# mean   2021-12-13 10:31:00.674157312     34.202247           2.125
# min              2021-12-01 00:00:00     17.000000             1.0
# 25%              2021-12-08 00:00:00     30.000000             1.0
# 50%              2021-12-13 00:00:00     35.000000             2.0
# 75%              2021-12-19 00:00:00     38.000000             3.0
# max              2021-12-24 00:00:00     63.000000             4.0
# std                              NaN      8.090651        1.239322
#
#          Unit_Cost   Unit_Price       Profit         Cost      Revenue
# count    89.000000    89.000000    89.000000    89.000000     89.00000
# mean   1052.247191  1940.943820  1848.887640  2204.235955   4043.94382
# min       0.000000     0.000000   245.000000     0.000000      0.00000
# 25%     420.000000  2295.000000  1043.000000  1252.000000   2295.00000
# ...

# %%
df1.isnull().mean() * 100
# Out:
# Sales_Order #          0.000000
# Date                   0.000000
# Customer_Age           0.000000
# Age_Group              1.123596
# Customer_Gender        0.000000
# Country                0.000000
# State                  0.000000
# Product_Category       0.000000
# Sub_Category           0.000000
# Product_Description    1.123596
# Order_Quantity         1.123596
# Unit_Cost              0.000000
# Unit_Price             0.000000
# Profit                 0.000000
# Cost                   0.000000
# Revenue                0.000000
# dtype: float64

# %%
df1[df1["Order_Quantity"].isnull()]
# Out:
#    Sales_Order #       Date  Customer_Age       Age_Group Customer_Gender  \
# 22        261716 2021-12-08            35  Adults (35-64)               F
#
#           Country       State Product_Category    Sub_Category  \
# 22  United States  California            Bikes  Mountain Bikes
#
#        Product_Description  Order_Quantity  Unit_Cost  Unit_Price  Profit  \
# 22  Mountain-500 Black, 42            <NA>        295         540     245
#
#     Cost  Revenue
# 22     0        0

# %%
df1["Order_Quantity"]=df1["Order_Quantity"].fillna(1)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sales_Order #        89 non-null     object
#  1   Date                 89 non-null     datetime64[ns]
#  2   Customer_Age         89 non-null     int64
#  3   Age_Group            88 non-null     object
#  4   Customer_Gender      89 non-null     object
#  5   Country              89 non-null     object
#  6   State                89 non-null     object
#  7   Product_Category     89 non-null     object
#  8   Sub_Category         89 non-null     object
#  9   Product_Description  88 non-null     object
#  10  Order_Quantity       89 non-null     Int64
#  11  Unit_Cost            89 non-null     int64
#  12  Unit_Price           89 non-null     int64
#  13  Profit               89 non-null     int64
#  14  Cost                 89 non-null     int64
# ...

# %%
df1.rename(columns={"Sales_Order #":"Sales_Order"},inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sales_Order          89 non-null     object
#  1   Date                 89 non-null     datetime64[ns]
#  2   Customer_Age         89 non-null     int64
#  3   Age_Group            88 non-null     object
#  4   Customer_Gender      89 non-null     object
#  5   Country              89 non-null     object
#  6   State                89 non-null     object
#  7   Product_Category     89 non-null     object
#  8   Sub_Category         89 non-null     object
#  9   Product_Description  88 non-null     object
#  10  Order_Quantity       89 non-null     Int64
#  11  Unit_Cost            89 non-null     int64
#  12  Unit_Price           89 non-null     int64
#  13  Profit               89 non-null     int64
#  14  Cost                 89 non-null     int64
# ...

# %%
sns.histplot(df1["Order_Quantity"])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
